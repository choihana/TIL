# %%
from zipfile import ZipFile
z = ZipFile('sentiment.zip')
data = z.open('sentiment labelled sentences/imdb_labelled.txt')

# %%
import pandas as pd
df = pd.read_csv(data, sep='\t', header = None)

# %% [markdown]
# ## TF-IDF
# 단어 빈도 * 역문서빈도
#
# `TfidfVectorizer`의 사용법은 `CountVectorizer`와 거의 동일하다.
#
# - stop_words : 분석에서 제외할 불용어를 설정하는 옵션이다. stop_words=english로 설정하면 영어의 경우 관사, 전치사 등을 제외한다.
# - max_features : 단어문서행렬에 포함시킬 최대(max)의 단어(feature) 수를 말한다. 즉, 빈도 순으로 최대 500 단어까지 포함한다.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(max_features=500, stop_words='english')

# %%
tdm = tfidf.fit_transform(df[0])

# %%
tdm
# Out:
# <748x500 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3433 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## 단어 빈도순 정렬

# %%
word_count = pd.DataFrame({
    '단어': tfidf.get_feature_names(),
    '빈도': tdm.sum(axis=0).flat
})

# %%
word_count.sort_values('빈도',ascending=False).head(50)
# Out:
#              단어         빈도
# 281       movie  43.842614
# 155        film  40.296277
# 31          bad  25.212655
# 227        just  20.498951
# 181        good  18.534937
# 437        time  13.422609
# 5        acting  12.535028
# 344      really  12.385831
# 240        like  12.215822
# 185       great  12.042639
# 0            10  11.430715
# 319        plot  10.439304
# 60   characters   9.698205
# 250        look   9.035191
# 37         best   8.562841
# 108         don   8.260823
# 369      script   8.205882
# 471    watching   8.199116
# 472         way   8.148038
# 282      movies   8.096180
# 373        seen   7.961242
# 59    character   7.958344
# 30        awful   7.847764
# 156       films   7.789146
# 56         cast   7.712904
# 343        real   7.359468
# 409       story   7.245328
# 256        love   7.143172
# 469       watch   6.891055
# 479   wonderful   6.729332
# 165       funny   6.492062
# 413      stupid   6.464597
# 489       worth   6.416441
# 365      scenes   6.240439
# 353       right   6.200097
# 433       think   6.137654
# 38       better   6.117684
# 8        actors   6.086059
# 231        know   6.021034
# 245      little   6.013703
# 483        work   5.896225
# 260        make   5.861728
# 284       music   5.643667
# 241       liked   5.451961
# 98         didn   5.444000
# 345   recommend   5.417326
# 135   excellent   5.339705
# 435     thought   5.323057
# 493     writing   5.200934
# 363       scene   5.151369
